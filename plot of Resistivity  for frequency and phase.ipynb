# %% [markdown]
# # plotting of curves of resistivity Vs frequency and phase

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %% [markdown]
# # model-1

# %%
df1=pd.read_csv("freq1.dat",sep="\s+",header=None)

# %%
df1.head(5)
# Out:
#      0    1         2    3         4
# 0  1.0  1.0  0.000096  1.0  0.005472
# 1  1.5  1.0  0.000143  1.0  0.008208
# 2  2.2  1.0  0.000210  1.0  0.012040
# 3  3.0  1.0  0.000287  1.0  0.016410
# 4  6.0  1.0  0.000573  1.0  0.032820

# %%
df1.columns=['freq','Real','Imag','Amp','Phase']

# %%
df1.head(5)
# Out:
#    freq  Real      Imag  Amp     Phase
# 0   1.0   1.0  0.000096  1.0  0.005472
# 1   1.5   1.0  0.000143  1.0  0.008208
# 2   2.2   1.0  0.000210  1.0  0.012040
# 3   3.0   1.0  0.000287  1.0  0.016410
# 4   6.0   1.0  0.000573  1.0  0.032820

# %%
freq=df1["freq"]
#freq

# %% [markdown]
# # finding the value of omega(w)

# %%
w=2*3.14*freq

# %% [markdown]
# # finding the value of 1/wu(1/omega*mu)

# %%
invert_const=w*4*3.14*1e-7

# %% [markdown]
# # here I  have taken const= /wu

# %%
const=1/invert_const

# %% [markdown]
# # for calculating the value of square of impedence

# %%
Amp_squared=(df["Amp"])**2

# %% [markdown]
# # calculting the value of apperent resistivity

# %%
res=const*Amp_squared
print(list(res),end=',')
# Out:
# [126779.99107468865, 84519.99404979243, 57627.268670313, 42259.99702489621, 21129.998512448106, 18111.42729638409, 12677.999107468864, 8451.999404979242, 5763.879470031975, 4226.844944690116, 2818.460180940403, 1812.9543251537298, 1270.0829775041582, 848.4147514436016, 580.66068049967, 428.0265595629302, 288.70657644439035, 189.91207988733242, 136.96706255831884, 96.02678354091445, 69.9066000280299, 54.718937634386776, 40.18510132256886, 28.74001136673178, 21.547954404844013],

# %% [markdown]
# # resistivity Vs frequency for model 1

# %%
plt.loglog(freq,res)
plt.xlabel("frequency1")
plt.ylabel("resistivity1")
plt.title("Resistivity1 Vs frequency1")
plt.grid()

# %%
phase1=df["Phase"]
#phase

# %%
plt.loglog(freq,phase1)
plt.xlabel("frequency1")
plt.ylabel("phase1")
plt.title("Resistivity2 Vs phase1")
plt.grid()

# %% [markdown]
# # model-2

# %%
df2=pd.read_csv("freq2.dat",sep="\s+",header=None)
#df2

# %%
df2.columns=['freq2','Real','Imag','Amp','Phase2']
#df2

# %%
freq2=df2["freq2"]
#freq2

# %%
w2=2*3.14*freq2

# %%
invert_const2=w2*4*3.14*1e-7

# %%
const2=1/invert_const2

# %%
Amp_squared2=(df["Amp"])**2

# %%
res2=const2*Amp_squared

# %%
phase2=df2["Phase2"]
#phase2

# %%
plt.loglog(freq2,res2)
plt.xlabel("frequency2")
plt.ylabel("resistivity")
plt.title("Resistivity Vs frequency2")
plt.grid()

# %%
plt.loglog(freq2,phase2)
plt.xlabel("frequency2")
plt.ylabel("phase2")
plt.title("phase2 Vs frequency2")
# Out:
# Text(0.5, 1.0, 'phase2 Vs frequency2')

# %% [markdown]
# # model-3

# %%
df3=pd.read_csv("freq3.dat",sep="\s+",header=None)
#df3

# %%
df3.columns=["freq","Real","Img","Amplitude","phase"]

# %%
df3.head(5)
# Out:
#    freq  Real       Img  Amplitude     phase
# 0   1.0   1.0  0.000105        1.0  0.006019
# 1   1.5   1.0  0.000158        1.0  0.009029
# 2   2.2   1.0  0.000231        1.0  0.013240
# 3   3.0   1.0  0.000315        1.0  0.018060
# 4   6.0   1.0  0.000630        1.0  0.036110

# %%
freq3=df3["freq"]
#freq2

# %%
w3=2*3.14*freq3

# %%
invert_const3=w3*4*3.14*1e-7

# %%
const3=1/invert_const3

# %%
Amp_squared3=(df["Amp"])**2

# %%
res3=const3*Amp_squared

# %%
phase3=df3["phase"]
#phase

# %%
plt.loglog(freq2,res2)
plt.xlabel("frequency3")
plt.ylabel("resistivity3")
plt.title("Resistivity Vs frequency3")
plt.grid()

# %%
plt.loglog(freq2,phase3)
plt.xlabel("frequency3")
plt.ylabel("phase3")
plt.title("phase3 Vs frequency3")
# Out:
# Text(0.5, 1.0, 'phase3 Vs frequency3')

# %% [markdown]
# # Model-4

# %%
df4=pd.read_csv("freq4.dat",sep="\s+",header=None)
#df4

# %%
df4.columns=["freq","Real","Img","Amplitude","phase"]

# %%
df4.head(5)
# Out:
#    freq  Real       Img  Amplitude     phase
# 0   1.0   1.0  0.000005        1.0  0.000273
# 1   1.5   1.0  0.000007        1.0  0.000410
# 2   2.2   1.0  0.000011        1.0  0.000602
# 3   3.0   1.0  0.000014        1.0  0.000822
# 4   6.0   1.0  0.000029        1.0  0.001648

# %%
freq4=df4["freq"]
#freq4

# %%
w4=2*3.14*freq4

# %%
invert_const4=w4*4*3.14*1e-7

# %%
const4=1/invert_const4

# %%
Amp_squared4=(df["Amp"])**2

# %%
res4=const4*Amp_squared

# %%
phase4=df4["phase"]
#phase

# %%
plt.loglog(freq4,res4)
plt.xlabel("frequency4")
plt.ylabel("resistivity4")
plt.title("Resistivity Vs frequency4")
plt.grid()

# %%
plt.loglog(freq2,phase4)
plt.xlabel("frequency4")
plt.ylabel("phase4")
plt.title("phase4 Vs frequency4")
# Out:
# Text(0.5, 1.0, 'phase4 Vs frequency4')

# %% [markdown]
# # END
